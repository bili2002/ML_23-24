# %% [markdown]
# # Linear Regression with `SciKit-Learn`

# %% [markdown]
# ## Imports

# %%
# Add the magic command for resetting the notebook state.

# %%
# Imports and constants here.

# %% [markdown]
# # Task 1 - Prepare data

# %% [markdown]
# ## Load Data
#
# - This sample data is from the lectures. It displays sales (in thousands of units) for a particular product as a function of advertising budgets (in thousands of dollars) for TV, radio, and newspaper media.
# - Load the dataset from [here](https://github.com/SimeonHristov99/ML_23-24/blob/main/DATA/Advertising.csv). Place the link in the `Imports` section.

# %%
# Out:
#         TV  radio  newspaper  sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3    9.3
# 3    151.5   41.3       58.5   18.5
# 4    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]

# %% [markdown]
# ### Expanding the Questions
#
# Previously, we explored **Is there a relationship between *total* advertising spend and *sales*?** as well as predicting the total sales for some value of total spend. Now we want to expand this to
#
# **What is the relationship between each advertising channel (TV,Radio,Newspaper) and sales?**

# %% [markdown]
# ### Multiple Features (N-Dimensional)

# %% [markdown]
# Use the `pairplot` function from `seaborn` to create scatter plots for every pair of features. Notice the row and column of the `sales` feature.

# %% [markdown]
# Split into `X` and `y`.

# %%
# Out:
#         TV  radio  newspaper
# 0    230.1   37.8       69.2
# 1     44.5   39.3       45.1
# 2     17.2   45.9       69.3
# 3    151.5   41.3       58.5
# 4    180.8   10.8       58.4
# ..     ...    ...        ...
# 195   38.2    3.7       13.8
# 196   94.2    4.9        8.1
# 197  177.0    9.3        6.4
# 198  283.6   42.0       66.2
# 199  232.1    8.6        8.7
#
# [200 rows x 3 columns]

# %%
# Out:
# 0      22.1
# 1      10.4
# 2       9.3
# 3      18.5
# 4      12.9
#        ...
# 195     7.6
# 196     9.7
# 197    12.8
# 198    25.5
# 199    13.4
# Name: sales, Length: 200, dtype: float64

# %% [markdown]
# Create a train-test split. The train split should have 30% of the data. Set the `random_state` to be `101`.
#
# > ***Note***: Add the import to the `Imports` section and not in the cell below. This is for better readability and easier maintenance.

# %% [markdown]
# Print the train data

# %%
# Out:
#         TV  radio  newspaper
# 85   193.2   18.4       65.7
# 183  287.6   43.0       71.8
# 127   80.2    0.0        9.2
# 53   182.6   46.2       58.7
# 100  222.4    4.3       49.8
# ..     ...    ...        ...
# 63   102.7   29.6        8.4
# 70   199.1   30.6       38.7
# 81   239.8    4.1       36.9
# 11   214.7   24.0        4.0
# 95   163.3   31.6       52.9
#
# [140 rows x 3 columns]

# %%
# Out:
# 85     15.2
# 183    26.2
# 127     8.8
# 53     21.2
# 100    11.7
#        ...
# 63     14.0
# 70     18.3
# 81     12.3
# 11     17.4
# 95     16.9
# Name: sales, Length: 140, dtype: float64

# %% [markdown]
# Print the test data

# %%
# Out:
#         TV  radio  newspaper
# 37    74.7   49.4       45.7
# 109  255.4   26.9        5.5
# 31   112.9   17.4       38.6
# 89   109.8   47.8       51.4
# 66    31.5   24.6        2.2
# 119   19.4   16.0       22.3
# 54   262.7   28.8       15.9
# 74   213.4   24.6       13.1
# 145  140.3    1.9        9.0
# 142  220.5   33.2       37.9
# 148   38.0   40.3       11.9
# 112  175.7   15.4        2.4
# 174  222.4    3.4       13.1
# 55   198.9   49.4       60.0
# 141  193.7   35.4       75.6
# 149   44.7   25.8       20.6
# 25   262.9    3.5       19.5
# 34    95.7    1.4        7.4
# 170   50.0   11.6       18.4
# 39   228.0   37.7       32.0
# 172   19.6   20.1       17.0
# 153  171.3   39.7       37.7
# 175  276.9   48.9       41.8
# 61   261.3   42.7       54.7
# 65    69.0    9.3        0.9
# 50   199.8    3.1       34.6
# 42   293.6   27.7        1.8
# 129   59.6   12.0       43.1
# 179  165.6   10.0       17.6
# 2     17.2   45.9       69.3
# 12    23.8   35.1       65.9
# ...

# %%
# Out:
# 37     14.7
# 109    19.8
# 31     11.9
# 89     16.7
# 66      9.5
# 119     6.6
# 54     20.2
# 74     17.0
# 145    10.3
# 142    20.1
# 148    10.9
# 112    14.1
# 174    11.5
# 55     23.7
# 141    19.2
# 149    10.1
# 25     12.0
# 34      9.5
# 170     8.4
# 39     21.5
# 172     7.6
# 153    19.0
# 175    27.0
# 61     24.2
# 65      9.3
# 50     11.4
# 42     20.7
# 129     9.7
# 179    12.6
# 2       9.3
# 12      9.2
# 133    19.6
# 90     11.2
# 22      5.6
# 41     17.1
# 32      9.6
# 125    10.6
# 196     9.7
# 158     7.3
# 180    10.5
# 16     12.5
# 186    10.3
# 144    11.4
# 121     7.0
# 80     11.8
# 18     11.3
# 78      5.3
# 48     14.8
# 4      12.9
# 15     22.4
# 1      10.4
# 43     12.9
# 102    14.8
# 164    11.9
# 9      10.6
# 155     3.2
# 36     25.4
# 190    10.8
# 33     17.4
# 45     14.9
# Name: sales, dtype: float64

# %% [markdown]
# # Task 2 - Creating a Model (Estimator)

# %% [markdown]
# Create an instance of the `LinearRegression` class in `sklearn`. Print it.
#
# > ***Hint***: To see the module in which the class is located feel free to jump to [the official scikit-learn documentation](https://scikit-learn.org/stable/index.html) and use the `search` bar in the top-right.

# %%
# Out:
# LinearRegression()

# %% [markdown]
# Fit/Train the Model on the training data using its `.fit` method.

# %%
# Out:
# LinearRegression()

# %% [markdown]
# # Task 3 - Evaluate the model

# %% [markdown]
# The three most common loss functions for regression problems are:
#
# **1. Mean Absolute Error** (MAE) is the mean of the absolute value of the errors:
#
# $$\frac 1n\sum_{i=1}^n|y_i-\hat{y}_i|$$
#
# **2. Mean Squared Error** (MSE) is the mean of the squared errors:
#
# $$\frac 1n\sum_{i=1}^n(y_i-\hat{y}_i)^2$$
#
# **3. Root Mean Squared Error** (RMSE) is the square root of the mean of the squared errors:
#
# $$\sqrt{\frac 1n\sum_{i=1}^n(y_i-\hat{y}_i)^2}$$
#
# Comparing them:
#
# - **MAE** is the easiest to understand, because it's the average error.
# - **MSE** is more popular than MAE, because MSE "punishes" larger errors, which tends to be useful in the real world.
# - **RMSE** is even more popular than MSE, because RMSE is interpretable in the "y" units.
#
# > ***Note***: All of these are **loss functions**, because we want to **minimize** them.

# %% [markdown]
# ### Calculate Performance on Test Set
#
# Apply the model on the test set. Print the values it predicts.

# %%
# Out:
# array([15.74131332, 19.61062568, 11.44888935, 17.00819787,  9.17285676,
#         7.01248287, 20.28992463, 17.29953992,  9.77584467, 19.22194224,
#        12.40503154, 13.89234998, 13.72541098, 21.28794031, 18.42456638,
#         9.98198406, 15.55228966,  7.68913693,  7.55614992, 20.40311209,
#         7.79215204, 18.24214098, 24.68631904, 22.82199068,  7.97962085,
#        12.65207264, 21.46925937,  8.05228573, 12.42315981, 12.50719678,
#        10.77757812, 19.24460093, 10.070269  ,  6.70779999, 17.31492147,
#         7.76764327,  9.25393336,  8.27834697, 10.58105585, 10.63591128,
#        13.01002595,  9.77192057, 10.21469861,  8.04572042, 11.5671075 ,
#        10.08368001,  8.99806574, 16.25388914, 13.23942315, 20.81493419,
#        12.49727439, 13.96615898, 17.56285075, 11.14537013, 12.56261468,
#         5.50870279, 23.29465134, 12.62409688, 18.77399978, 15.18785675])

# %% [markdown]
# Calculate the `MAE`:
# 1. manually using `numpy` in one line.
# 2. using `sklearn`
#
# The results should be identical.

# %%
# manual
# Out:
# 1.2137457736144805

# %%
# using sklearn
# Out:
# 1.2137457736144805

# %% [markdown]
# Calculate the `MSE`:
# 1. manually using `numpy` in one line.
# 2. using `sklearn`
#
# The results should be identical.

# %%
# manual
# Out:
# 2.298716697886378

# %%
# using sklearn
# Out:
# 2.298716697886378

# %% [markdown]
# Calculate the `MSE`:
# 1. manually using `numpy` in one line.
# 2. using `sklearn`
#
# The results should be identical.
#
# > ***Hint***: Can you reuse the previous calculations?

# %%
# manual
# Out:
# 1.5161519375993877

# %%
# using sklearn
# Out:
# 1.5161519375993877

# %% [markdown]
# Calculate the mean of the `sales` column.
#
# Answer the following question: **What does the `RMSE` tell you about the performance of the model?**

# %%
# Out:
# 14.0225

# %% [markdown]
# # Task 4 - Interpreting model coefficients

# %% [markdown]
# Display the model coefficients.

# %%
# Out:
# array([ 0.04469599,  0.1875657 , -0.00032275])

# %% [markdown]
# Map them to the variable names. The coefficient at position `i` corresponds to the `i`<sup>th</sup> variable.

# %%
# Out:
#            Coefficient
# TV            0.044696
# radio         0.187566
# newspaper    -0.000323

# %% [markdown]
# Interpreting the coefficients:
#
# * Holding all other features fixed, a 1 unit (A thousand dollars) increase in TV Spend is associated with an increase in sales of  0.045 "sales units", in this case 1000s of units .
# * This basically means that for every $1000 dollars spend on TV Ads, we could expect 45 more units sold.
#
# ----
#
# * Holding all other features fixed, a 1 unit (A thousand dollars) increase in Radio Spend is associated with an increase in sales of  0.188 "sales units", in this case 1000s of units .
# * This basically means that for every $1000 dollars spend on Radio Ads, we could expect 188 more units sold.
#
# ----
#
# * Holding all other features fixed, a 1 unit (A thousand dollars) increase in Newspaper Spend is associated with a **decrease** in sales of  0.0003 "sales units", in this case 1000s of units .
# * This basically means that for every $1000 dollars spend on Newspaper Ads, we could actually expect to not sell any more units or even sell `1 unit less`. Being so close to 0, this heavily implies that newspaper spend has no real effect on sales.

# %% [markdown]
# # Task 5
#
# Our next ad campaign will have a total spend of 149k on `TV`, 22k on `Radio`, and 12k on `Newspaper Ads`, how many units could we expect to sell as a result of this?

# %%
# Out:
# array([13.93380216])

# %% [markdown]
# # Task 6 - Why exploratory data analysis is beneficial
#
# Let's see why visualizing our data is important. You can refer to [the official Wikipedia article](https://en.wikipedia.org/wiki/Anscombe%27s_quartet) for more details.
#
# Load all `anscombes_quartet*.csv` files. Please define the paths in the `Imports` section.

# %%
# Out:
#        x      y
# 0   10.0   8.04
# 1    8.0   6.95
# 2   13.0   7.58
# 3    9.0   8.81
# 4   11.0   8.33
# 5   14.0   9.96
# 6    6.0   7.24
# 7    4.0   4.26
# 8   12.0  10.84
# 9    7.0   4.82
# 10   5.0   5.68

# %%
# Out:
#        x     y
# 0   10.0  9.14
# 1    8.0  8.14
# 2   13.0  8.74
# 3    9.0  8.77
# 4   11.0  9.26
# 5   14.0  8.10
# 6    6.0  6.13
# 7    4.0  3.10
# 8   12.0  9.13
# 9    7.0  7.26
# 10   5.0  4.74

# %%
# Out:
#        x      y
# 0    8.0   6.58
# 1    8.0   5.76
# 2    8.0   7.71
# 3    8.0   8.84
# 4    8.0   8.47
# 5    8.0   7.04
# 6    8.0   5.25
# 7   19.0  12.50
# 8    8.0   5.56
# 9    8.0   7.91
# 10   8.0   6.89

# %% [markdown]
# Display summary statistics for each of them. What do you notice?

# %%
# Out:
#    count      mean       std   min    25%   50%    75%    max
# x   11.0  9.000000  3.316625  4.00  6.500  9.00  11.50  14.00
# y   11.0  7.500909  2.031568  4.26  6.315  7.58   8.57  10.84

# %%
# Out:
#    count      mean       std  min    25%   50%    75%    max
# x   11.0  9.000000  3.316625  4.0  6.500  9.00  11.50  14.00
# y   11.0  7.500909  2.031657  3.1  6.695  8.14   8.95   9.26

# %%
# Out:
#    count      mean       std   min   25%   50%   75%   max
# x   11.0  9.000000  3.316625  8.00  8.00  8.00  8.00  19.0
# y   11.0  7.500909  2.030579  5.25  6.17  7.04  8.19  12.5

# %% [markdown]
# Plot each of them

# %% [markdown]
# Fit a linear regression to `quartet2` and checks it's `RMSE`.
#
# Usually, it's bad practice to train and evaluate the model on the full data, but for illustrative purposes:
# 1. Train the model on the full data.
# 2. Print the `RMSE` on the full data.
#
# Notice how the value is quite low, however, after visualizing this data we should know better and not use these model for anything serious.

# %%
# Out:
# RMSE: 1.1185497916336298
# RMSE: 1.1191023557497446
# RMSE: 1.1177286221293936
